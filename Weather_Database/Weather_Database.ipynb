# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
#create a cities list
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # add city to list if not already in list of cities
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 717

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create list to hold city weather data
city_data = []

#print beginning of the logs
print("Beginning Data Retrieval     ")
print("-----------------------------")

# create counters
city_record = 1
record_set = 1
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging
    if (i % 50 == 0 and i >= 50):
        record_set += 1
        city_record = 1
    # create url for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log the url, record, and set number and the city.
    print(f"Processing Record {city_record} of Set {record_set} | {city}")
    
    #Add one to the record count
    city_record += 1
    try:
        city_weather = requests.get(city_url).json()
          
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Weather": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | margate
# Processing Record 2 of Set 1 | los llanos de aridane
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | ballina
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | hamilton
# Processing Record 7 of Set 1 | jinchang
# Processing Record 8 of Set 1 | rundu
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | hasaki
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | pangody
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | valparaiso
# Processing Record 19 of Set 1 | boyuibe
# Processing Record 20 of Set 1 | mehamn
# Processing Record 21 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 1 | rodrigues alves
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | isangel
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | whitehorse
# Processing Record 29 of Set 1 | batamshinskiy
# Processing Record 30 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 1 | berbera
# Processing Record 32 of Set 1 | pisco
# Processing Record 33 of Set 1 | kaitangata
# Processing Record 34 of Set 1 | north vanlaiphai
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 1 | paamiut
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | clarence town
# Processing Record 45 of Set 1 | potosi
# Processing Record 46 of Set 1 | bandarbeyla
# Processing Record 47 of Set 1 | butaritari
# Processing Record 48 of Set 1 | salalah
# Processing Record 49 of Set 1 | homer
# Processing Record 50 of Set 1 | port talbot
# Processing Record 1 of Set 2 | norman wells
# Processing Record 2 of Set 2 | padang
# Processing Record 3 of Set 2 | nome
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 2 | necochea
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | harlingen
# Processing Record 10 of Set 2 | portales
# Processing Record 11 of Set 2 | guadalupe victoria
# Processing Record 12 of Set 2 | adrar
# Processing Record 13 of Set 2 | kyshtovka
# Processing Record 14 of Set 2 | la joya
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | ati
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 2 | roald
# Processing Record 19 of Set 2 | nizhniy odes
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | sapa
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | bridlington
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | sibiti
# Processing Record 29 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 2 | praia da vitoria
# Processing Record 31 of Set 2 | bathsheba
# Processing Record 32 of Set 2 | esso
# Processing Record 33 of Set 2 | korla
# Processing Record 34 of Set 2 | kabare
# Processing Record 35 of Set 2 | yingzhong
# City not found. Skipping...
# Processing Record 36 of Set 2 | marrakesh
# Processing Record 37 of Set 2 | esperance
# Processing Record 38 of Set 2 | jamestown
# Processing Record 39 of Set 2 | vila velha
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | saint-pierre
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | marevo
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | okhotsk
# Processing Record 49 of Set 2 | boende
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | oranjemund
# Processing Record 2 of Set 3 | lagoa
# Processing Record 3 of Set 3 | carutapera
# Processing Record 4 of Set 3 | dingle
# Processing Record 5 of Set 3 | sisimiut
# Processing Record 6 of Set 3 | rincon
# Processing Record 7 of Set 3 | hobart
# Processing Record 8 of Set 3 | kieta
# Processing Record 9 of Set 3 | klaksvik
# Processing Record 10 of Set 3 | lingao
# Processing Record 11 of Set 3 | bilibino
# Processing Record 12 of Set 3 | stornoway
# Processing Record 13 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 3 | souillac
# Processing Record 15 of Set 3 | lavrentiya
# Processing Record 16 of Set 3 | tocopilla
# Processing Record 17 of Set 3 | scarborough
# Processing Record 18 of Set 3 | saint-joseph
# Processing Record 19 of Set 3 | poum
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | saint-leu
# Processing Record 22 of Set 3 | narsaq
# Processing Record 23 of Set 3 | tiksi
# Processing Record 24 of Set 3 | chokurdakh
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | aklavik
# Processing Record 27 of Set 3 | pevek
# Processing Record 28 of Set 3 | san lazaro
# Processing Record 29 of Set 3 | hay river
# Processing Record 30 of Set 3 | taltal
# Processing Record 31 of Set 3 | nanortalik
# Processing Record 32 of Set 3 | ahumada
# City not found. Skipping...
# Processing Record 33 of Set 3 | kruisfontein
# Processing Record 34 of Set 3 | bosaso
# Processing Record 35 of Set 3 | san cristobal
# Processing Record 36 of Set 3 | beyneu
# Processing Record 37 of Set 3 | arona
# Processing Record 38 of Set 3 | ottawa
# Processing Record 39 of Set 3 | ciudad bolivar
# Processing Record 40 of Set 3 | flin flon
# Processing Record 41 of Set 3 | songea
# Processing Record 42 of Set 3 | kopyevo
# City not found. Skipping...
# Processing Record 43 of Set 3 | dom pedrito
# Processing Record 44 of Set 3 | camacha
# Processing Record 45 of Set 3 | saskylakh
# Processing Record 46 of Set 3 | purpe
# Processing Record 47 of Set 3 | talnakh
# Processing Record 48 of Set 3 | victoria
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | samfya
# Processing Record 1 of Set 4 | ikom
# Processing Record 2 of Set 4 | ambilobe
# Processing Record 3 of Set 4 | alice springs
# Processing Record 4 of Set 4 | baoying
# Processing Record 5 of Set 4 | kudahuvadhoo
# Processing Record 6 of Set 4 | upernavik
# Processing Record 7 of Set 4 | muskogee
# Processing Record 8 of Set 4 | erzin
# Processing Record 9 of Set 4 | iquique
# Processing Record 10 of Set 4 | nouadhibou
# Processing Record 11 of Set 4 | cassilandia
# Processing Record 12 of Set 4 | aksu
# Processing Record 13 of Set 4 | husavik
# Processing Record 14 of Set 4 | acapulco
# Processing Record 15 of Set 4 | tottori
# Processing Record 16 of Set 4 | lasa
# Processing Record 17 of Set 4 | north bend
# Processing Record 18 of Set 4 | saint-philippe
# Processing Record 19 of Set 4 | high level
# Processing Record 20 of Set 4 | tera
# Processing Record 21 of Set 4 | faanui
# Processing Record 22 of Set 4 | catamarca
# Processing Record 23 of Set 4 | great falls
# Processing Record 24 of Set 4 | thompson
# Processing Record 25 of Set 4 | bethel
# Processing Record 26 of Set 4 | phek
# Processing Record 27 of Set 4 | uruzgan
# Processing Record 28 of Set 4 | methven
# Processing Record 29 of Set 4 | maniitsoq
# Processing Record 30 of Set 4 | katangli
# Processing Record 31 of Set 4 | nioro
# Processing Record 32 of Set 4 | fuling
# Processing Record 33 of Set 4 | sayat
# Processing Record 34 of Set 4 | mahebourg
# Processing Record 35 of Set 4 | toledo
# Processing Record 36 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 4 | roanoke rapids
# Processing Record 38 of Set 4 | fort nelson
# Processing Record 39 of Set 4 | shache
# Processing Record 40 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 4 | severo-kurilsk
# Processing Record 42 of Set 4 | fairbanks
# Processing Record 43 of Set 4 | nsanje
# Processing Record 44 of Set 4 | craig
# Processing Record 45 of Set 4 | melita
# Processing Record 46 of Set 4 | marsh harbour
# Processing Record 47 of Set 4 | saint anthony
# Processing Record 48 of Set 4 | torbay
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 4 | road town
# Processing Record 1 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 2 of Set 5 | mount gambier
# Processing Record 3 of Set 5 | qinhuangdao
# Processing Record 4 of Set 5 | santana do matos
# Processing Record 5 of Set 5 | pangnirtung
# Processing Record 6 of Set 5 | bredasdorp
# Processing Record 7 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 5 | cherskiy
# Processing Record 9 of Set 5 | bud
# Processing Record 10 of Set 5 | cape elizabeth
# City not found. Skipping...
# Processing Record 11 of Set 5 | avera
# Processing Record 12 of Set 5 | senador guiomard
# Processing Record 13 of Set 5 | eyl
# Processing Record 14 of Set 5 | aquiraz
# Processing Record 15 of Set 5 | bambous virieux
# Processing Record 16 of Set 5 | vestmannaeyjar
# Processing Record 17 of Set 5 | tasiilaq
# Processing Record 18 of Set 5 | wajid
# Processing Record 19 of Set 5 | kirishi
# Processing Record 20 of Set 5 | belmonte
# Processing Record 21 of Set 5 | salisbury
# Processing Record 22 of Set 5 | iqaluit
# Processing Record 23 of Set 5 | westport
# Processing Record 24 of Set 5 | bartica
# Processing Record 25 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 5 | hami
# Processing Record 27 of Set 5 | adamas
# Processing Record 28 of Set 5 | komsomolskiy
# Processing Record 29 of Set 5 | lompoc
# Processing Record 30 of Set 5 | raudeberg
# Processing Record 31 of Set 5 | meulaboh
# Processing Record 32 of Set 5 | ciudad guayana
# Processing Record 33 of Set 5 | baft
# Processing Record 34 of Set 5 | hofn
# Processing Record 35 of Set 5 | greeley
# Processing Record 36 of Set 5 | sitka
# Processing Record 37 of Set 5 | jishou
# Processing Record 38 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 5 | fort-shevchenko
# Processing Record 40 of Set 5 | dinghai
# Processing Record 41 of Set 5 | altay
# Processing Record 42 of Set 5 | berlevag
# Processing Record 43 of Set 5 | longyearbyen
# Processing Record 44 of Set 5 | jilin
# Processing Record 45 of Set 5 | arraial do cabo
# Processing Record 46 of Set 5 | sorland
# Processing Record 47 of Set 5 | lorengau
# Processing Record 48 of Set 5 | constantine
# Processing Record 49 of Set 5 | zhangye
# Processing Record 50 of Set 5 | tuktoyaktuk
# Processing Record 1 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 6 | alta floresta
# Processing Record 3 of Set 6 | sao filipe
# Processing Record 4 of Set 6 | provideniya
# Processing Record 5 of Set 6 | saint george
# Processing Record 6 of Set 6 | sovetskiy
# Processing Record 7 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 8 of Set 6 | rio grande
# Processing Record 9 of Set 6 | inverness
# Processing Record 10 of Set 6 | baykit
# Processing Record 11 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 6 | valdez
# Processing Record 13 of Set 6 | coquimbo
# Processing Record 14 of Set 6 | mnogovershinnyy
# Processing Record 15 of Set 6 | colac
# Processing Record 16 of Set 6 | barcelos
# Processing Record 17 of Set 6 | havoysund
# Processing Record 18 of Set 6 | san carlos
# Processing Record 19 of Set 6 | maridi
# Processing Record 20 of Set 6 | zhezkazgan
# Processing Record 21 of Set 6 | soeng sang
# Processing Record 22 of Set 6 | nedjo
# Processing Record 23 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 6 | zhigansk
# Processing Record 25 of Set 6 | syava
# Processing Record 26 of Set 6 | sao joao batista
# Processing Record 27 of Set 6 | denpasar
# Processing Record 28 of Set 6 | celestun
# Processing Record 29 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 30 of Set 6 | paulo afonso
# Processing Record 31 of Set 6 | fortuna
# Processing Record 32 of Set 6 | sept-iles
# Processing Record 33 of Set 6 | lapithos
# Processing Record 34 of Set 6 | tevaitoa
# Processing Record 35 of Set 6 | kankan
# Processing Record 36 of Set 6 | yako
# Processing Record 37 of Set 6 | la asuncion
# Processing Record 38 of Set 6 | georgetown
# Processing Record 39 of Set 6 | inirida
# Processing Record 40 of Set 6 | kismayo
# Processing Record 41 of Set 6 | aksarka
# Processing Record 42 of Set 6 | yambio
# Processing Record 43 of Set 6 | college
# Processing Record 44 of Set 6 | dunedin
# Processing Record 45 of Set 6 | portland
# Processing Record 46 of Set 6 | neiafu
# Processing Record 47 of Set 6 | waingapu
# Processing Record 48 of Set 6 | luau
# Processing Record 49 of Set 6 | durres
# Processing Record 50 of Set 6 | biltine
# Processing Record 1 of Set 7 | lebu
# Processing Record 2 of Set 7 | manicore
# Processing Record 3 of Set 7 | bac lieu
# Processing Record 4 of Set 7 | piney green
# Processing Record 5 of Set 7 | balkanabat
# Processing Record 6 of Set 7 | itarema
# Processing Record 7 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 7 | freeport
# Processing Record 9 of Set 7 | heihe
# Processing Record 10 of Set 7 | kommunisticheskiy
# Processing Record 11 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 7 | castro
# Processing Record 13 of Set 7 | matay
# Processing Record 14 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 7 | siguiri
# Processing Record 16 of Set 7 | sobolevo
# Processing Record 17 of Set 7 | sorong
# Processing Record 18 of Set 7 | elizabeth city
# Processing Record 19 of Set 7 | ust-nera
# Processing Record 20 of Set 7 | kahului
# Processing Record 21 of Set 7 | chipinge
# Processing Record 22 of Set 7 | damara
# Processing Record 23 of Set 7 | yumen
# Processing Record 24 of Set 7 | chokwe
# Processing Record 25 of Set 7 | harper
# Processing Record 26 of Set 7 | san jeronimo
# Processing Record 27 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 7 | benguela
# Processing Record 29 of Set 7 | naze
# Processing Record 30 of Set 7 | bubaque
# Processing Record 31 of Set 7 | nagato
# Processing Record 32 of Set 7 | oistins
# Processing Record 33 of Set 7 | tuatapere
# Processing Record 34 of Set 7 | leningradskiy
# Processing Record 35 of Set 7 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 36 of Set 7 | plouzane
# Processing Record 37 of Set 7 | siocon
# Processing Record 38 of Set 7 | pathanamthitta
# Processing Record 39 of Set 7 | ust-kulom
# Processing Record 40 of Set 7 | hualmay
# Processing Record 41 of Set 7 | carnarvon
# Processing Record 42 of Set 7 | anjar
# Processing Record 43 of Set 7 | muli
# Processing Record 44 of Set 7 | kavieng
# Processing Record 45 of Set 7 | deep river
# Processing Record 46 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 7 | acarau
# Processing Record 48 of Set 7 | fengzhen
# Processing Record 49 of Set 7 | soubre
# Processing Record 50 of Set 7 | poitiers
# Processing Record 1 of Set 8 | paungde
# Processing Record 2 of Set 8 | lucea
# Processing Record 3 of Set 8 | sibu
# Processing Record 4 of Set 8 | lima
# Processing Record 5 of Set 8 | doha
# Processing Record 6 of Set 8 | broome
# Processing Record 7 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 8 of Set 8 | vao
# Processing Record 9 of Set 8 | key west
# Processing Record 10 of Set 8 | grindavik
# Processing Record 11 of Set 8 | chusovoy
# Processing Record 12 of Set 8 | vardo
# Processing Record 13 of Set 8 | kasane
# Processing Record 14 of Set 8 | mutis
# Processing Record 15 of Set 8 | comodoro rivadavia
# Processing Record 16 of Set 8 | honningsvag
# Processing Record 17 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 8 | gravelbourg
# Processing Record 19 of Set 8 | bayshore gardens
# Processing Record 20 of Set 8 | bokspits
# City not found. Skipping...
# Processing Record 21 of Set 8 | hamadan
# Processing Record 22 of Set 8 | grand gaube
# Processing Record 23 of Set 8 | tual
# Processing Record 24 of Set 8 | iwanai
# Processing Record 25 of Set 8 | kaihua
# Processing Record 26 of Set 8 | warmbad
# Processing Record 27 of Set 8 | birao
# Processing Record 28 of Set 8 | nishihara
# Processing Record 29 of Set 8 | eureka
# Processing Record 30 of Set 8 | kefamenanu
# Processing Record 31 of Set 8 | buenos aires
# Processing Record 32 of Set 8 | labuhan
# Processing Record 33 of Set 8 | chalinze
# Processing Record 34 of Set 8 | turukhansk
# Processing Record 35 of Set 8 | juneau
# Processing Record 36 of Set 8 | gat
# Processing Record 37 of Set 8 | sinjah
# City not found. Skipping...
# Processing Record 38 of Set 8 | hatillo
# Processing Record 39 of Set 8 | beringovskiy
# Processing Record 40 of Set 8 | nauta
# Processing Record 41 of Set 8 | mankono
# Processing Record 42 of Set 8 | lardos
# Processing Record 43 of Set 8 | promyshlennovskiy
# Processing Record 44 of Set 8 | krasnoselkup
# Processing Record 45 of Set 8 | pucallpa
# Processing Record 46 of Set 8 | rawson
# Processing Record 47 of Set 8 | clyde river
# Processing Record 48 of Set 8 | kavaratti
# Processing Record 49 of Set 8 | gravdal
# Processing Record 50 of Set 8 | kishorganj
# Processing Record 1 of Set 9 | mount darwin
# Processing Record 2 of Set 9 | katsuura
# Processing Record 3 of Set 9 | cabedelo
# Processing Record 4 of Set 9 | caconda
# Processing Record 5 of Set 9 | kenai
# Processing Record 6 of Set 9 | jiaozuo
# Processing Record 7 of Set 9 | mrakovo
# Processing Record 8 of Set 9 | biryusinsk
# Processing Record 9 of Set 9 | auki
# Processing Record 10 of Set 9 | kuytun
# Processing Record 11 of Set 9 | barra do garcas
# Processing Record 12 of Set 9 | arak
# Processing Record 13 of Set 9 | hovd
# Processing Record 14 of Set 9 | dawei
# Processing Record 15 of Set 9 | umm kaddadah
# Processing Record 16 of Set 9 | barkly west
# Processing Record 17 of Set 9 | kijang
# Processing Record 18 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 19 of Set 9 | manzhouli
# Processing Record 20 of Set 9 | nemuro
# Processing Record 21 of Set 9 | nikolayevka
# Processing Record 22 of Set 9 | tanda
# Processing Record 23 of Set 9 | dungarpur
# Processing Record 24 of Set 9 | port hedland
# Processing Record 25 of Set 9 | santiago de cao
# Processing Record 26 of Set 9 | huarmey
# Processing Record 27 of Set 9 | kysyl-syr
# Processing Record 28 of Set 9 | santiago del estero
# Processing Record 29 of Set 9 | conceicao do araguaia
# Processing Record 30 of Set 9 | quthing
# Processing Record 31 of Set 9 | sabha
# Processing Record 32 of Set 9 | naliya
# Processing Record 33 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 34 of Set 9 | constitucion
# Processing Record 35 of Set 9 | luderitz
# Processing Record 36 of Set 9 | mecca
# Processing Record 37 of Set 9 | pontianak
# Processing Record 38 of Set 9 | rock springs
# Processing Record 39 of Set 9 | baikunthpur
# Processing Record 40 of Set 9 | plettenberg bay
# Processing Record 41 of Set 9 | mersin
# Processing Record 42 of Set 9 | codrington
# Processing Record 43 of Set 9 | salitral
# Processing Record 44 of Set 9 | coihaique
# Processing Record 45 of Set 9 | cidreira
# Processing Record 46 of Set 9 | marsa matruh
# Processing Record 47 of Set 9 | oriximina
# Processing Record 48 of Set 9 | mitsamiouli
# Processing Record 49 of Set 9 | waddan
# Processing Record 50 of Set 9 | ostersund
# Processing Record 1 of Set 10 | itoman
# Processing Record 2 of Set 10 | port augusta
# Processing Record 3 of Set 10 | san carlos de bariloche
# Processing Record 4 of Set 10 | geraldton
# Processing Record 5 of Set 10 | arbuzynka
# Processing Record 6 of Set 10 | valentin gomez farias
# Processing Record 7 of Set 10 | saint-augustin
# Processing Record 8 of Set 10 | afogados da ingazeira
# Processing Record 9 of Set 10 | kambove
# Processing Record 10 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 10 | ngama
# Processing Record 12 of Set 10 | balad
# Processing Record 13 of Set 10 | porto novo
# Processing Record 14 of Set 10 | glubokoe
# City not found. Skipping...
# Processing Record 15 of Set 10 | channel-port aux basques
# Processing Record 16 of Set 10 | pocone
# Processing Record 17 of Set 10 | saint-francois
# Processing Record 18 of Set 10 | goderich
# Processing Record 19 of Set 10 | kearney
# Processing Record 20 of Set 10 | pacific grove
# Processing Record 21 of Set 10 | bulgan
# Processing Record 22 of Set 10 | camacupa
# Processing Record 23 of Set 10 | gilgit
# Processing Record 24 of Set 10 | lugovoy
# Processing Record 25 of Set 10 | tabou
# Processing Record 26 of Set 10 | chardara
# Processing Record 27 of Set 10 | emirdag
# Processing Record 28 of Set 10 | edson
# Processing Record 29 of Set 10 | manaure
# Processing Record 30 of Set 10 | acajutla
# Processing Record 31 of Set 10 | kasongo-lunda
# Processing Record 32 of Set 10 | catalina
# Processing Record 33 of Set 10 | aswan
# Processing Record 34 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 10 | luyang
# Processing Record 36 of Set 10 | batagay-alyta
# Processing Record 37 of Set 10 | artyom
# Processing Record 38 of Set 10 | pandan
# Processing Record 39 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 10 | gigmoto
# Processing Record 41 of Set 10 | yar-sale
# Processing Record 42 of Set 10 | tabuk
# Processing Record 43 of Set 10 | hailun
# Processing Record 44 of Set 10 | lanzhou
# Processing Record 45 of Set 10 | puerto del rosario
# Processing Record 46 of Set 10 | manzil jamil
# City not found. Skipping...
# Processing Record 47 of Set 10 | srednekolymsk
# Processing Record 48 of Set 10 | raga
# Processing Record 49 of Set 10 | dalvik
# Processing Record 50 of Set 10 | kuvshinovo
# Processing Record 1 of Set 11 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 2 of Set 11 | tarko-sale
# Processing Record 3 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 11 | mahibadhoo
# Processing Record 5 of Set 11 | calabozo
# Processing Record 6 of Set 11 | aguimes
# Processing Record 7 of Set 11 | asekeyevo
# Processing Record 8 of Set 11 | kiunga
# Processing Record 9 of Set 11 | tarakan
# Processing Record 10 of Set 11 | oyama
# Processing Record 11 of Set 11 | amahai
# Processing Record 12 of Set 11 | yatou
# Processing Record 13 of Set 11 | sri aman
# Processing Record 14 of Set 11 | hibbing
# Processing Record 15 of Set 11 | ormara
# Processing Record 16 of Set 11 | magadan
# Processing Record 17 of Set 11 | tura
# Processing Record 18 of Set 11 | florianopolis
# Processing Record 19 of Set 11 | la rioja
# Processing Record 20 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 21 of Set 11 | kokopo
# Processing Record 22 of Set 11 | pochutla
# Processing Record 23 of Set 11 | kushmurun
# Processing Record 24 of Set 11 | waipawa
# Processing Record 25 of Set 11 | axim
# Processing Record 26 of Set 11 | quatre cocos
# Processing Record 27 of Set 11 | tazmalt
# Processing Record 28 of Set 11 | yanam
# Processing Record 29 of Set 11 | lexington park
# Processing Record 30 of Set 11 | churapcha
# Processing Record 31 of Set 11 | namibe
# Processing Record 32 of Set 11 | octeville
# Processing Record 33 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 11 | te anau
# Processing Record 35 of Set 11 | saldanha
# Processing Record 36 of Set 11 | middletown
# Processing Record 37 of Set 11 | guerrero negro
# Processing Record 38 of Set 11 | lashio
# Processing Record 39 of Set 11 | sibolga
# Processing Record 40 of Set 11 | dekoa
# City not found. Skipping...
# Processing Record 41 of Set 11 | hambantota
# Processing Record 42 of Set 11 | muroto
# Processing Record 43 of Set 11 | shimoda
# Processing Record 44 of Set 11 | vichayal
# City not found. Skipping...
# Processing Record 45 of Set 11 | lesnoy
# Processing Record 46 of Set 11 | moindou
# Processing Record 47 of Set 11 | camara de lobos
# Processing Record 48 of Set 11 | anan
# Processing Record 49 of Set 11 | otradnoye
# Processing Record 50 of Set 11 | zhuhai
# Processing Record 1 of Set 12 | san juan del cesar
# Processing Record 2 of Set 12 | port ellen
# City not found. Skipping...
# Processing Record 3 of Set 12 | shelburne
# Processing Record 4 of Set 12 | hammerfest
# Processing Record 5 of Set 12 | petrolina
# Processing Record 6 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 7 of Set 12 | aykino
# Processing Record 8 of Set 12 | acari
# Processing Record 9 of Set 12 | krasnorechenskiy
# Processing Record 10 of Set 12 | jacareacanga
# Processing Record 11 of Set 12 | paita
# Processing Record 12 of Set 12 | caarapo
# Processing Record 13 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 12 | bossangoa
# Processing Record 15 of Set 12 | richards bay
# Processing Record 16 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 17 of Set 12 | sinnamary
# Processing Record 18 of Set 12 | shahrud
# Processing Record 19 of Set 12 | ambon
# Processing Record 20 of Set 12 | hurghada
# Processing Record 21 of Set 12 | batangafo
# Processing Record 22 of Set 12 | novopavlovka
# Processing Record 23 of Set 12 | marawi
# Processing Record 24 of Set 12 | keshorai patan
# Processing Record 25 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 12 | naroda
# Processing Record 27 of Set 12 | ngunguru
# Processing Record 28 of Set 12 | viedma
# Processing Record 29 of Set 12 | kropotkin
# Processing Record 30 of Set 12 | omsukchan
# Processing Record 31 of Set 12 | samarai
# Processing Record 32 of Set 12 | dubbo
# Processing Record 33 of Set 12 | biak
# Processing Record 34 of Set 12 | karlovy vary
# Processing Record 35 of Set 12 | barreirinhas
# Processing Record 36 of Set 12 | isabela
# Processing Record 37 of Set 12 | thoen
# Processing Record 38 of Set 12 | anito
# Processing Record 39 of Set 12 | llangefni
# Processing Record 40 of Set 12 | huangchuan
# Processing Record 41 of Set 12 | mount isa
# Processing Record 42 of Set 12 | kargopol
# Processing Record 43 of Set 12 | puerto padre
# Processing Record 44 of Set 12 | rio verde de mato grosso
# Processing Record 45 of Set 12 | catia la mar
# Processing Record 46 of Set 12 | najran
# Processing Record 47 of Set 12 | lerwick
# Processing Record 48 of Set 12 | puerto escondido
# Processing Record 49 of Set 12 | paytug
# City not found. Skipping...
# Processing Record 50 of Set 12 | cabo san lucas
# Processing Record 1 of Set 13 | vanimo
# Processing Record 2 of Set 13 | sur
# Processing Record 3 of Set 13 | cockburn town
# Processing Record 4 of Set 13 | vung tau
# Processing Record 5 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 6 of Set 13 | a coruna
# Processing Record 7 of Set 13 | mala
# Processing Record 8 of Set 13 | kulykiv
# Processing Record 9 of Set 13 | rio gallegos
# Processing Record 10 of Set 13 | phuket
# Processing Record 11 of Set 13 | porto velho
# Processing Record 12 of Set 13 | huambo
# Processing Record 13 of Set 13 | tondano
# Processing Record 14 of Set 13 | erzurum
# Processing Record 15 of Set 13 | kedrovyy
# Processing Record 16 of Set 13 | yulara
# Processing Record 17 of Set 13 | odweyne
# Processing Record 18 of Set 13 | yaring
# Processing Record 19 of Set 13 | moerai
# Processing Record 20 of Set 13 | sistranda
# Processing Record 21 of Set 13 | broken hill
# Processing Record 22 of Set 13 | taoudenni
# Processing Record 23 of Set 13 | faaborg
# Processing Record 24 of Set 13 | cayenne
# Processing Record 25 of Set 13 | charagua
# Processing Record 26 of Set 13 | sharjah
# Processing Record 27 of Set 13 | mutum
# Processing Record 28 of Set 13 | guarda
# Processing Record 29 of Set 13 | dali
# Processing Record 30 of Set 13 | sorkjosen
# Processing Record 31 of Set 13 | fairview
# Processing Record 32 of Set 13 | ketchikan
# Processing Record 33 of Set 13 | dwarka
# Processing Record 34 of Set 13 | ostrovnoy
# Processing Record 35 of Set 13 | tiznit
# Processing Record 36 of Set 13 | sao sebastiao
# Processing Record 37 of Set 13 | vanavara
# Processing Record 38 of Set 13 | yabrud
# Processing Record 39 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 40 of Set 13 | nalut
# Processing Record 41 of Set 13 | pese
# Processing Record 42 of Set 13 | san vicente
# Processing Record 43 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 44 of Set 13 | faya
# Processing Record 45 of Set 13 | salta
# Processing Record 46 of Set 13 | bonavista
# Processing Record 47 of Set 13 | guthrie
# Processing Record 48 of Set 13 | griffith
# Processing Record 49 of Set 13 | quelimane
# Processing Record 50 of Set 13 | tadine
# Processing Record 1 of Set 14 | purace
# City not found. Skipping...
# Processing Record 2 of Set 14 | ordubad
# Processing Record 3 of Set 14 | ihosy
# Processing Record 4 of Set 14 | buchanan
# Processing Record 5 of Set 14 | port-gentil
# Processing Record 6 of Set 14 | samana
# Processing Record 7 of Set 14 | camana
# Processing Record 8 of Set 14 | kautokeino
# Processing Record 9 of Set 14 | smidovich
# Processing Record 10 of Set 14 | longhua
# Processing Record 11 of Set 14 | mpika
# Processing Record 12 of Set 14 | zhanaozen
# Processing Record 13 of Set 14 | ayagoz
# Processing Record 14 of Set 14 | poronaysk
# Processing Record 15 of Set 14 | albanel
# Processing Record 16 of Set 14 | lata
# Processing Record 17 of Set 14 | san luis
# Processing Record 18 of Set 14 | kamiiso
# Processing Record 19 of Set 14 | havre-saint-pierre
# Processing Record 20 of Set 14 | eston
# Processing Record 21 of Set 14 | port lincoln
# Processing Record 22 of Set 14 | vila franca do campo
# Processing Record 23 of Set 14 | san rafael
# Processing Record 24 of Set 14 | kashi
# Processing Record 25 of Set 14 | atherton
# Processing Record 26 of Set 14 | kathmandu
# Processing Record 27 of Set 14 | boulder
# Processing Record 28 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 29 of Set 14 | matagami
# Processing Record 30 of Set 14 | beatrice
# Processing Record 31 of Set 14 | moron
# Processing Record 32 of Set 14 | maragogi
# Processing Record 33 of Set 14 | simao
# Processing Record 34 of Set 14 | the valley
# Processing Record 35 of Set 14 | staraya poltavka
# Processing Record 36 of Set 14 | amalfi
# Processing Record 37 of Set 14 | maungaturoto
# Processing Record 38 of Set 14 | san juan de los morros
# Processing Record 39 of Set 14 | opunake
# Processing Record 40 of Set 14 | salmas
# Processing Record 41 of Set 14 | waitati
# Processing Record 42 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 43 of Set 14 | anadyr
# Processing Record 44 of Set 14 | russell
# Processing Record 45 of Set 14 | ahipara
# Processing Record 46 of Set 14 | talagang
# Processing Record 47 of Set 14 | kaeo
# Processing Record 48 of Set 14 | pozega
# Processing Record 49 of Set 14 | matehuala
# Processing Record 50 of Set 14 | san juan de la vega
# Processing Record 1 of Set 15 | tambo
# Processing Record 2 of Set 15 | asau
# Processing Record 3 of Set 15 | ouesso
# Processing Record 4 of Set 15 | rovaniemi
# Processing Record 5 of Set 15 | christchurch
# Processing Record 6 of Set 15 | zyryanka
# Processing Record 7 of Set 15 | jiamusi
# Processing Record 8 of Set 15 | magan
# Processing Record 9 of Set 15 | naujamiestis
# Processing Record 10 of Set 15 | madison
# Processing Record 11 of Set 15 | mayumba
# Processing Record 12 of Set 15 | bauru
# Processing Record 13 of Set 15 | trenggalek
# Processing Record 14 of Set 15 | bathurst
# Processing Record 15 of Set 15 | xianyang
# Processing Record 16 of Set 15 | dubenskiy
# City not found. Skipping...
# Processing Record 17 of Set 15 | pangoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng   Current Weather  Max Temp  \
# 0                Margate  51.3813    1.3862   overcast clouds     60.69
# 1  Los Llanos De Aridane  28.6585  -17.9182     broken clouds     69.12
# 2           Punta Arenas -53.1500  -70.9167  scattered clouds     42.91
# 3                Ballina -28.8667  153.5667   overcast clouds     67.96
# 4         Ribeira Grande  38.5167  -28.7000     broken clouds     73.18
# 5               Hamilton  39.1834  -84.5333              haze     80.73
# 6               Jinchang  38.4953  102.1739     broken clouds     73.36
# 7                  Rundu -17.9333   19.7667         clear sky     55.49
# 8                  Bluff -46.6000  168.3333   overcast clouds     44.80
# 9              Cape Town -33.9258   18.4232        few clouds     57.11
#
#    Humidity  Cloudiness  Wind Speed Country                 Date
# 0        83          97        1.99      GB  2021-08-01 22:34:26
# 1        68          75       19.57      ES  2021-08-01 22:36:59
# 2        75          40       17.27      CL  2021-08-01 22:32:14
# 3        77          90       10.36      AU  2021-08-01 22:41:00
# 4        94          63       13.49      PT  2021-08-01 22:34:00
# 5        62          20        3.00      US  2021-08-01 22:34:41
# 6        37          79        3.22      CN  2021-08-01 22:38:00
# 7        44           0        6.33      NA  2021-08-01 22:43:05
# 8        82          98        6.35      NZ  2021-08-01 22:35:55
# 9        84          20        1.01      ZA  2021-08-01 22:35:37

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Weather"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City Country                 Date      Lat       Lng  \
# 0                Margate      GB  2021-08-01 22:34:26  51.3813    1.3862
# 1  Los Llanos De Aridane      ES  2021-08-01 22:36:59  28.6585  -17.9182
# 2           Punta Arenas      CL  2021-08-01 22:32:14 -53.1500  -70.9167
# 3                Ballina      AU  2021-08-01 22:41:00 -28.8667  153.5667
# 4         Ribeira Grande      PT  2021-08-01 22:34:00  38.5167  -28.7000
# 5               Hamilton      US  2021-08-01 22:34:41  39.1834  -84.5333
# 6               Jinchang      CN  2021-08-01 22:38:00  38.4953  102.1739
# 7                  Rundu      NA  2021-08-01 22:43:05 -17.9333   19.7667
# 8                  Bluff      NZ  2021-08-01 22:35:55 -46.6000  168.3333
# 9              Cape Town      ZA  2021-08-01 22:35:37 -33.9258   18.4232
#
#    Max Temp  Humidity  Cloudiness  Wind Speed   Current Weather
# 0     60.69        83          97        1.99   overcast clouds
# 1     69.12        68          75       19.57     broken clouds
# 2     42.91        75          40       17.27  scattered clouds
# 3     67.96        77          90       10.36   overcast clouds
# 4     73.18        94          63       13.49     broken clouds
# 5     80.73        62          20        3.00              haze
# 6     73.36        37          79        3.22     broken clouds
# 7     55.49        44           0        6.33         clear sky
# 8     44.80        82          98        6.35   overcast clouds
# 9     57.11        84          20        1.01        few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
